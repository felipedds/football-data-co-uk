# %%
# %sql
CREATE CATALOG IF NOT EXISTS `football_data_co_uk`;
USE CATALOG `football_data_co_uk`;

CREATE DATABASE IF NOT EXISTS `football_data_co_uk_database`;
USE `football_data_co_uk_database`;

CREATE VOLUME IF NOT EXISTS `football_data_co_uk`.`football_data_co_uk_database`.`football_data_co_uk_raw_volume`;

# %%
dbutils.fs.mkdirs("/Volumes/football_data_co_uk/football_data_co_uk_database/football_data_co_uk_raw_volume/premier_league")
