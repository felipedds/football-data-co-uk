# %%
# %sql
CREATE CATALOG IF NOT EXISTS `football_data_co_uk`;
USE CATALOG `football_data_co_uk`;

# %%
# %sql
CREATE DATABASE IF NOT EXISTS `football_data_co_uk_database`;
USE `football_data_co_uk_database`;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS `football_data_co_uk`.`football_data_co_uk_database`.`football_data_co_uk_raw`;
CREATE VOLUME IF NOT EXISTS `football_data_co_uk`.`football_data_co_uk_database`.`football_data_co_uk_bronze`;

# %%
dbutils.fs.mkdirs("/Volumes/football_data_co_uk/football_data_co_uk_database/football_data_co_uk_raw/premier_league")
dbutils.fs.mkdirs("/Volumes/football_data_co_uk/football_data_co_uk_database/football_data_co_uk_bronze/premier_league")
