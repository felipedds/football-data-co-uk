# %% [markdown]
# ### Bronze Layer

# %%
import pandas as pd
from pyspark.sql import SparkSession


spark = SparkSession.builder.appName("premier_league_bronze").getOrCreate()

# File
parquet_file = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/bronze/premier_league/2021_E0.parquet"

# Read o CSV
spark_df = spark.createDataFrame(pd.read_parquet(parquet_file))

spark_df.show(5)

# %% [markdown]
# ### Silver Layer

# %%
spark = SparkSession.builder.appName("premier_league_silver").getOrCreate()

# File
consolidated_data_silver = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/silver/premier_league/consolidated_data.parquet"

# Read o CSV
df_silver = spark.createDataFrame(pd.read_parquet(consolidated_data_silver))

df_silver.show(5)

# %% [markdown]
# ### Gold Layer

# %%
spark = SparkSession.builder.appName("premier_league_gold").getOrCreate()

# File
consolidated_data_gold = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/gold/premier_league/enriched_data.parquet"

# Read o CSV
df_gold = spark.createDataFrame(pd.read_parquet(consolidated_data_gold))

df_gold.show(5)

# %% [markdown]
# ## View Table

# %%
df_gold.createOrReplaceTempView("gold_table")

# %%
# %sql
SELECT 
HomeTeam, COUNT(*) as total_matches
FROM gold_table
GROUP BY HomeTeam
ORDER BY total_matches DESC
