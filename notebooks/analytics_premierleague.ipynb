# %%
import pandas as pd
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("premier_league").getOrCreate()

# File
parquet_file = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/bronze/2021_E0.parquet"

# Read o CSV
spark_df = spark.createDataFrame(pd.read_parquet(parquet_file))

spark_df.show(5)
