# %% [markdown]
# ### Bronze Layer

# %%
import pandas as pd
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("premier_league_bronze").getOrCreate()

# File
parquet_file = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/bronze/2021_E0.parquet"

# Read o CSV
spark_df = spark.createDataFrame(pd.read_parquet(parquet_file))

spark_df.show(5)

# %% [markdown]
# ### Silver Layer

# %%
spark = SparkSession.builder.appName("premier_league_silver").getOrCreate()

# File
consolidated_data_silver = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/silver/consolidated_data.parquet"

# Read o CSV
df_silver = spark.createDataFrame(pd.read_parquet(consolidated_data_silver))

df_silver.show(5)

# %% [markdown]
# ### Gold Layer

# %%
spark = SparkSession.builder.appName("premier_league_gold").getOrCreate()

# File
consolidated_data_gold = "/Workspace/Repos/felipediasd@gmail.com/football-data-co-uk/data/gold/enriched_data.parquet"

# Read o CSV
df_gold = spark.createDataFrame(pd.read_parquet(consolidated_data_gold))

df_gold.show(5)
